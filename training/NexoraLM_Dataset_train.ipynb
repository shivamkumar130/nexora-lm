# %%
# Clone
# !git clone https://github.com/shivamkumar130/nexora-lm.git
# %cd nexora-lm

# %%
# Install
# !pip install -r requirements.txt
# !pip install faiss-cpu

# %%
# Rebuild knowledge
# !python knowledge/faiss/build_index.py

# %%
# Retrain tokenizer
# !python tokenizer/train_tokenizer.py

# %%
# Rebuild corpus
# !python training/data/build_training_corpus.py

# %%
# Train
# !python -m training.train_data

# %%
# Evaluate

# !python -m training.evaluate

# %%
# !python -m inference.engine.load_model

# %%
# !python -m tests.benchmarks.generation_benchmark

# %%
# Test
# !python -m tests.integration.system_test
